# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

data = pd.read_csv('Vgsales1.csv', index_col='Name')
data.head()
# Out:
#                           Rank Platform    Year         Genre Publisher  \
# Name
# Wii Sports                   1      Wii  2006.0        Sports  Nintendo
# Super Mario Bros.            2      NES  1985.0      Platform  Nintendo
# Mario Kart Wii               3      Wii  2008.0        Racing  Nintendo
# Wii Sports Resort            4      Wii  2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue     5       GB  1996.0  Role-Playing  Nintendo
#
#                           NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                   41.49     29.02      3.77         8.46
# Super Mario Bros.            29.08      3.58      6.81         0.77
# Mario Kart Wii               15.85     12.88      3.79         3.31
# Wii Sports Resort            15.75     11.01      3.28         2.96
# Pokemon Red/Pokemon Blue     11.27      8.89     10.22         1.00
#
#                           Global_Sales
# Name
# Wii Sports                       82.74
# ...

# %%
data.columns
# Out:
# Index(['Rank', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
required_info = data[['Rank', 'Platform', 'Year', 'Genre', 'Publisher']]
required_info.head()
# Out:
#                           Rank Platform    Year         Genre Publisher
# Name
# Wii Sports                   1      Wii  2006.0        Sports  Nintendo
# Super Mario Bros.            2      NES  1985.0      Platform  Nintendo
# Mario Kart Wii               3      Wii  2008.0        Racing  Nintendo
# Wii Sports Resort            4      Wii  2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue     5       GB  1996.0  Role-Playing  Nintendo

# %%
required_info.dropna(inplace=True)
# Out:
# <ipython-input-8-953540fed462>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   required_info.dropna(inplace=True)

# %%
encoder = LabelEncoder()
for i in list(required_info.columns):
    encoder.fit(required_info[i])
    required_info[i] = encoder.transform(required_info[i])
required_info.head()
# Out:
# <ipython-input-10-67d8188c57e2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   required_info[i] = encoder.transform(required_info[i])
#                           Rank  Platform  Year  Genre  Publisher
# Name
# Wii Sports                   0        26    26     10        359
# Super Mario Bros.            1        11     5      4        359
# Mario Kart Wii               2        26    28      6        359
# Wii Sports Resort            3        26    29     10        359
# Pokemon Red/Pokemon Blue     4         5    16      7        359

# %%
required_info = required_info.T
required_info.head()
# Out:
# Name       Wii Sports  Super Mario Bros.  Mario Kart Wii  Wii Sports Resort  \
# Rank                0                  1               2                  3
# Platform           26                 11              26                 26
# Year               26                  5              28                 29
# Genre              10                  4               6                 10
# Publisher         359                359             359                359
#
# Name       Pokemon Red/Pokemon Blue  Tetris  New Super Mario Bros.  Wii Play  \
# Rank                              4       5                      6         7
# Platform                          5       5                      4        26
# Year                             16       9                     26        26
# Genre                             7       5                      4         3
# Publisher                       359     359                    359       359
#
# ...

# %%
recent_played = required_info['Duck Hunt']
related = required_info.corrwith(recent_played)
related.sort_values(ascending= False).head(10)
# Out:
# Name
# Duck Hunt                        1.000000
# Super Mario Bros.                0.999746
# Tetris                           0.999647
# Super Mario World                0.999239
# Super Mario Bros. 3              0.999181
# Gran Turismo 3: A-Spec           0.998965
# Pokemon Red/Pokemon Blue         0.998956
# Super Mario Land                 0.998933
# Grand Theft Auto: San Andreas    0.998797
# Grand Theft Auto: Vice City      0.998777
# dtype: float64
